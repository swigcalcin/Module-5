# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.
#
#  We see that Capomulin and Ramicane may be the most effective regarding the research. The mean tumor volume of both durgs is 10 points below the rest of drugs tested. The more effective drugs have less variance as well. Propriva may be the least effective of the drug. Sex of mice most likely does not have an affect on the tumor volume but the weight of the mice may have a correlation.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data_df = pd.merge(study_results, mouse_metadata, how = 'outer', on = "Mouse ID")


# Display the data table for preview
combined_data_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
number_of_mice = len(combined_data_df["Mouse ID"].unique())

number_of_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicate_mice = combined_data_df.loc[combined_data_df.duplicated(subset=["Mouse ID", "Timepoint"], keep=False), "Mouse ID"].unique()

duplicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_data_df = combined_data_df[combined_data_df['Mouse ID'] == 'g989'].copy()

duplicate_data_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data_df = combined_data_df[combined_data_df["Mouse ID"] != "g989"]

clean_data_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice in the clean DataFrame.
clean_number_mice = len(clean_data_df["Mouse ID"].unique())
                        
clean_number_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.


means = clean_data_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
medians = clean_data_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variances = clean_data_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
sds = clean_data_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sems = clean_data_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()


summary_table = pd.DataFrame({"Mean Tumor Volume":means,
                              "Median Tumor Volume":medians,
                              "Tumor Volume Variance":variances,
                              "Tumor Volume Std. Dev.":sds,
                              "Tumor Volume Std. Err.":sems})
summary_table
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

summary_table = clean_data_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(
    Mean=('mean'),
    Median=('median'),
    Variance=('var'),
    Standard_Deviation=('std'),
    SEM=('sem')
)

summary_table
# Out:
#                    Mean     Median   Variance  Standard_Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

regimen_counts = clean_data_df.groupby('Drug Regimen').size()

regimen_counts.plot(kind='bar')

plt.xlabel('Drug Regimen')
plt.ylabel("of Observed Mouse Timepoints")

plt.xticks(rotation=45)


plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

regimen_pyplot_graph = clean_data_df['Drug Regimen'].value_counts()

plt.bar(regimen_pyplot_graph.index, regimen_pyplot_graph.values)


plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.xticks(rotation=45)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

sex_counts = clean_data_df["Sex"].value_counts()

sex_counts.plot(kind='pie', autopct='%1.1f%%')


plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

sex_counts = clean_data_df["Sex"].value_counts()

plt.pie(sex_counts, labels=sex_counts.index, autopct="%1.1f%%")


plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
regimen_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
filtered_df = clean_data_df[clean_data_df["Drug Regimen"].isin(regimen_list)]

# Start by getting the last (greatest) timepoint for each mouse
last_timepoints = filtered_df.groupby("Mouse ID")["Timepoint"].max()
last_timepoints = last_timepoints.reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor_volume_df = last_timepoints.merge(clean_data_df, on=["Mouse ID", "Timepoint"]
)

final_tumor_volume_df
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      a203         45           67.973419                 2    Infubinol
# 1      a251         45           65.525743                 1    Infubinol
# 2      a275         45           62.999356                 3     Ceftamin
# 3      a411         45           38.407618                 1     Ramicane
# 4      a444         45           43.047543                 0     Ramicane
# ..      ...        ...                 ...               ...          ...
# 95     y769         45           68.594745                 4     Ceftamin
# 96     y793         45           31.896238                 2    Capomulin
# 97     y865         45           64.729837                 3     Ceftamin
# 98     z578         45           30.638696                 0     Ramicane
# 99     z581         45           62.754451                 3    Infubinol
#
#        Sex  Age_months  Weight (g)
# 0   Female          20          23
# ...

# %%
# Put treatments into a list for the loop
drugs = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create an empty list to fill with tumor volume data for plotting
vol_data = []

# Calculate the IQR and determine potential outliers for each treatment
for drug in drugs:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    treatment_df = final_tumor_volume_df[final_tumor_volume_df["Drug Regimen"] == drug]
    tumor_volumes = treatment_df["Tumor Volume (mm3)"]
    
    # Add the tumor volumes to the vol_data list
    vol_data.append(tumor_volumes)
    
    # Calculate the IQR for the current treatment
    quartiles = tumor_volumes.quantile([0.25, 0.5, 0.75])
    lower_bound = quartiles[0.25] - 1.5 * (quartiles[0.75] - quartiles[0.25])
    upper_bound = quartiles[0.75] + 1.5 * (quartiles[0.75] - quartiles[0.25])
    
    # Determine outliers using upper and lower bounds
    outliers = tumor_volumes[(tumor_volumes < lower_bound) | (tumor_volumes > upper_bound)]

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.boxplot(vol_data, labels=drugs)


plt.ylabel("Final Tumor Volume (mm3)")

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
capomulin_df = clean_data_df.loc[clean_data_df["Drug Regimen"] == "Capomulin"]

sample_capomulin = capomulin_df.loc[capomulin_df["Mouse ID"]=="l509"]

time_points = sample_capomulin["Timepoint"]
tumor_volumes = sample_capomulin["Tumor Volume (mm3)"]

plt.plot(time_points, tumor_volumes)
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin l509")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

capomulin_df = clean_data_df.loc[clean_data_df["Drug Regimen"] == "Capomulin"]


grouped_data = capomulin_df.groupby(['Mouse ID'])[['Weight (g)', 'Tumor Volume (mm3)']].mean()


plt.scatter(grouped_data['Weight (g)'],grouped_data['Tumor Volume (mm3)'])
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
# Assuming you have the final_tumor_volume_df DataFrame containing the final tumor volume data



plt.scatter(grouped_data['Weight (g)'], grouped_data['Tumor Volume (mm3)'])
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")


correlation_coefficient, _ = st.pearsonr(grouped_data['Weight (g)'], grouped_data['Tumor Volume (mm3)'])
print("Correlation Coefficient:", correlation_coefficient)


slope, intercept, _, _, _ = st.linregress(grouped_data['Weight (g)'], grouped_data['Tumor Volume (mm3)'])


regression_line = slope * grouped_data['Weight (g)'] + intercept


plt.plot(grouped_data['Weight (g)'], regression_line, color="red")


plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")


plt.show()
# Out:
# Correlation Coefficient: 0.8419363424694719
